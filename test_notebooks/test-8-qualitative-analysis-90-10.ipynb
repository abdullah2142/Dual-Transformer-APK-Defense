# %% [markdown]
# # Test 8: Qualitative Error Analysis of False Negatives
#
# This notebook isolates the False Negatives (actual malware predicted as safe) from the GraphCodeBERT validation set, and prints the raw source code for the top 10 most confident mistakes.
#
# **Goal**: Identify structural patterns in missed vulnerabilities (e.g., extremely short functions, specific CWEs, or SQL injections) to provide transparent qualitative analysis for the paper.
#
# **Kaggle Environment Details**:
# - Dataset: `/kaggle/input/datasets/hasanmahmudabdullah/dfgdataset2/dataset_graphcodebert.jsonl`
# - Model: `/kaggle/input/datasets/hasanmahmudabdullah/model2/model.bin`

# %%
import torch
import json
import numpy as np
from transformers import AutoTokenizer, RobertaConfig, RobertaModel
from torch.utils.data import DataLoader, SequentialSampler, Dataset, random_split
from tqdm.auto import tqdm
import torch.nn as nn
import torch.nn.functional as F
from torch.nn import CrossEntropyLoss

print("Imports complete.")
# Out:
# Imports complete.

# %%
class Args:
    code_length = 384
    data_flow_length = 128
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    eval_batch_size = 32
    seed = 42
    
args = Args()

class Model(nn.Module):   
    def __init__(self, encoder, config, tokenizer, args):
        super(Model, self).__init__()
        self.encoder = encoder
        self.config = config
        self.tokenizer = tokenizer
        self.args = args
        
        # Classification Head
        self.dropout = nn.Dropout(config.hidden_dropout_prob)
        self.classifier = nn.Linear(config.hidden_size, 2) # 0 or 1

    def forward(self, input_ids=None, p_ids=None, attn_mask=None, labels=None): 
        if input_ids is not None:
            extended_attention_mask = (1.0 - attn_mask) * -10000.0
            extended_attention_mask = extended_attention_mask.unsqueeze(1)
            
            embedding_output = self.encoder.embeddings(
                input_ids=input_ids, 
                position_ids=p_ids
            )

            encoder_outputs = self.encoder.encoder(
                embedding_output,
                attention_mask=extended_attention_mask,
                head_mask=[None] * self.config.num_hidden_layers
            )
            
            sequence_output = encoder_outputs[0]
            logits = self.classifier(self.dropout(sequence_output[:, 0, :]))
            prob = F.softmax(logits, dim=-1)

            if labels is not None:
                loss_fct = CrossEntropyLoss()
                loss = loss_fct(logits, labels)
                return loss, prob
            else:
                return prob

# %%
class TextDataset(Dataset):
    def __init__(self, tokenizer, args, file_path):
        self.args = args
        self.tokenizer = tokenizer
        self.total_len = args.code_length + args.data_flow_length
        
        with open(file_path, 'r') as f:
            self.lines = f.readlines()
            
    def __len__(self):
        return len(self.lines)

    def _get_char_index(self, code_lines, coord):
        row, col = coord
        char_idx = 0
        for i in range(min(row, len(code_lines))):
            char_idx += len(code_lines[i]) 
        return char_idx + col

    def __getitem__(self, item):
        line = self.lines[item]
        # Store the raw index for easy lookup later
        self.last_item_idx = item
        
        entry = json.loads(line)
        code = entry.get('code', '')
        dfg = entry.get('dfg', [])[:self.args.data_flow_length]
        label = int(entry.get('label', 0)) if entry.get('label') is not None else 0

        tokens_obj = self.tokenizer(
            code, 
            max_length=self.args.code_length, 
            truncation=True, 
            padding='max_length',
            return_offsets_mapping=True
        )
        input_ids = tokens_obj['input_ids']
        offsets = tokens_obj['offset_mapping']
        code_lines = code.splitlines(keepends=True)

        dfg_ids = [self.tokenizer.unk_token_id] * len(dfg)
        node_to_token_map = {}
        pos_to_node_idx = {}

        for node_idx, node_item in enumerate(dfg):
            start_pos = node_item[1][0]
            end_pos = node_item[1][1]
            pos_key = (start_pos[0], start_pos[1], end_pos[0], end_pos[1])
            pos_to_node_idx[pos_key] = node_idx
            
            try:
                char_start = self._get_char_index(code_lines, start_pos)
                char_end = self._get_char_index(code_lines, end_pos)
                aligned_tokens = []
                for t_idx, (t_start, t_end) in enumerate(offsets):
                    if t_start == t_end: continue
                    if (t_start >= char_start and t_end <= char_end) or \
                       (char_start >= t_start and char_end <= t_end):
                        aligned_tokens.append(t_idx)
                node_to_token_map[node_idx] = aligned_tokens
            except IndexError:
                node_to_token_map[node_idx] = []

        total_len = self.args.code_length + len(dfg)
        attn_mask = np.zeros((self.total_len, self.total_len), dtype=bool)
        c_len = self.args.code_length
        attn_mask[:c_len, :c_len] = True
        
        for node_idx, node_item in enumerate(dfg):
            abs_node_idx = c_len + node_idx
            tokens = node_to_token_map.get(node_idx, [])
            for t_idx in tokens:
                attn_mask[abs_node_idx, t_idx] = True
                attn_mask[t_idx, abs_node_idx] = True
            
            parent_positions = node_item[4]
            for p_pos in parent_positions:
                p_key = (p_pos[0][0], p_pos[0][1], p_pos[1][0], p_pos[1][1])
                if p_key in pos_to_node_idx:
                    parent_idx = pos_to_node_idx[p_key]
                    abs_parent_idx = c_len + parent_idx
                    attn_mask[abs_node_idx, abs_parent_idx] = True
                    attn_mask[abs_parent_idx, abs_node_idx] = True 
            attn_mask[abs_node_idx, abs_node_idx] = True

        full_input_ids = input_ids + dfg_ids
        p_ids = [i + 2 for i in range(c_len)] + [0] * len(dfg_ids)
        padding_len = self.total_len - len(full_input_ids)
        
        if padding_len > 0:
            full_input_ids += [self.tokenizer.pad_token_id] * padding_len
            p_ids += [1] * padding_len
        
        return {
            'input_ids': torch.tensor(full_input_ids, dtype=torch.long),
            'p_ids': torch.tensor(p_ids, dtype=torch.long),
            'attn_mask': torch.tensor(attn_mask, dtype=torch.float),
            'label': torch.tensor(label, dtype=torch.long),
            'index': item
        }

# %%
print("Loading dataset...")
tokenizer = AutoTokenizer.from_pretrained("microsoft/graphcodebert-base", use_fast=True)
dataset_path = "/kaggle/input/datasets/hasanmahmudabdullah/dfgdataset2/dataset_graphcodebert.jsonl"
full_dataset = TextDataset(tokenizer, args, dataset_path)

# 90/10 train/test split — analyse the held-out test set
n       = len(full_dataset)
train_n = int(0.9 * n)
test_n  = n - train_n

generator = torch.Generator().manual_seed(args.seed)
_, test_ds = random_split(full_dataset, [train_n, test_n], generator=generator)

print(f"Test samples isolated: {len(test_ds)}")
# Out:
# Loading dataset...
# config.json:   0%|          | 0.00/539 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/772 [00:00<?, ?B/s]
# Test samples isolated: 19996

# %%
print("Loading GraphCodeBERT model...")
config = RobertaConfig.from_pretrained("microsoft/graphcodebert-base")
config.num_labels = 2
encoder = RobertaModel.from_pretrained("microsoft/graphcodebert-base", config=config)
model = Model(encoder, config, tokenizer, args)

model_path = "/kaggle/input/notebooks/hasanmahmudabdullah2/graphcodebert-v2-training/saved_models/model.bin"
model.load_state_dict(torch.load(model_path, map_location=args.device))
model.to(args.device)
model.eval()
print("Model loaded successfully!")
# Out:
# Loading GraphCodeBERT model...
# pytorch_model.bin:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/197 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: microsoft/graphcodebert-base
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.decoder.bias            | UNEXPECTED |
# lm_head.decoder.weight          | UNEXPECTED |
# pooler.dense.bias               | MISSING    |
# pooler.dense.weight             | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Model loaded successfully!

# %%
eval_sampler = SequentialSampler(test_ds)
eval_dataloader = DataLoader(test_ds, sampler=eval_sampler, batch_size=args.eval_batch_size)

all_preds = []
all_labels = []
all_probs = []
all_indices = []

print("Running inference on test set...")
with torch.no_grad():
    for batch in tqdm(eval_dataloader, desc="Evaluating"):
        input_ids = batch['input_ids'].to(args.device)
        p_ids = batch['p_ids'].to(args.device)
        attn_mask = batch['attn_mask'].to(args.device)
        labels = batch['label'].to(args.device)
        indices = batch['index']
        
        probs = model(input_ids=input_ids, p_ids=p_ids, attn_mask=attn_mask)
        preds = torch.argmax(probs, dim=-1)
        
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
        all_probs.extend(probs[:, 1].cpu().numpy())
        all_indices.extend(indices.numpy())
# Out:
# Running inference on test set...
# Evaluating:   0%|          | 0/625 [00:00<?, ?it/s]

# %%
false_negatives = []

for i, (pred, label, prob, raw_idx) in enumerate(zip(all_preds, all_labels, all_probs, all_indices)):
    if label == 1 and pred == 0:
        # Get the original JSON line to extract code and metadata
        raw_line = full_dataset.lines[raw_idx]
        raw_data = json.loads(raw_line)
        
        false_negatives.append({
            'index': raw_idx,
            'confidence_safe': 1.0 - prob,
            'code': raw_data.get('code', 'N/A'),
            'project': raw_data.get('filename', 'Unknown')
        })

print(f"\nTotal False Negatives Found in Test Set: {len(false_negatives)}")

# Sort by how confident the model was that it was SAFE (worst mistakes first)
false_negatives.sort(key=lambda x: x['confidence_safe'], reverse=True)

print("\n======================================================")
print("Analyzing the Top 20 Most Confident False Negatives:")
print("======================================================\n")

for i, fn in enumerate(false_negatives[:20]):
    print(f"[False Negative #{i+1}] - Originally from '{fn['project']}'")
    print(f"Model Confidence it was SAFE: {fn['confidence_safe'] * 100:.2f}%")
    print("-" * 40)
    lines = fn['code'].split('\n')
    
    # Print up to 35 lines of code
    max_lines = 35
    print('\n'.join(lines[:max_lines]))
    if len(lines) > max_lines:
        print(f"... [Truncated {len(lines) - max_lines} more lines]")
    print("=" * 60 + "\n")
# Out:
# Total False Negatives Found in Test Set: 1184
#
# ======================================================
# Analyzing the Top 20 Most Confident False Negatives:
# ======================================================
#
# [False Negative #1] - Originally from 'LVDAndro_83233_file'
# Model Confidence it was SAFE: 99.99%
# ----------------------------------------
# public class DummyClass { public void dummyMethod() { private ProgressDialog field_1000;
# private Activity field_1001 = null;
# public class_336(Activity var1, class_22 var2) {
# this.field_996 = var2;
# static Activity method_1192(class_336 var0) {
# protected class_308 method_1193(class_281... var1) {
# protected void method_1194(class_308 var1) {
# this.field_1000.dismiss();
# this.field_996.method_58(var1);
# return this.method_1193((class_281[])var1);
# this.method_1194((class_308)var1); } }
# ============================================================
#
# [False Negative #2] - Originally from 'LVDAndro_128605_file'
# Model Confidence it was SAFE: 99.99%
# ----------------------------------------
# public class DummyClass { public void dummyMethod() { private ProgressDialog field_1347;
# private Activity field_1348 = null;
# private class_22 field_1349 = null;
# public class_443(Activity var1, class_22 var2) {
# static Activity method_1455(class_443 var0) {
# protected class_308 method_1456(Void... var1) {
# protected void method_1457(class_308 var1) {
# this.field_1347.dismiss();
# this.field_1349.method_58(var1);
# return this.method_1456((Void[])var1);
# this.method_1457((class_308)var1); } }
# ============================================================
#
# [False Negative #3] - Originally from 'LVDAndro_225549_file'
# Model Confidence it was SAFE: 99.99%
# ----------------------------------------
# public class DummyClass { public void dummyMethod() { array4[i] = n21;
# if (i == n19) {
# final int n24 = n15 - 1;
# if ((n23 = n24) > 0) {
# n22 = data5.readUnsignedIntToInt() - 1;
# n25 = n10 + unsignedIntToInt6;
# final int n26 = --unsignedIntToInt9;
# unsignedIntToInt11 = unsignedIntToInt6;
# unsignedIntToInt9 = n26;
# unsignedIntToInt9 = data4.readUnsignedIntToInt();
# n27 = n6 - 1; } }
# ============================================================
#
# [False Negative #4] - Originally from 'LVDAndro_38620_file'
# Model Confidence it was SAFE: 99.98%
# ----------------------------------------
# public class DummyClass { public void dummyMethod() { this.fill = sTPathFillMode;
# public void setH(long l) {
# public void setStroke(boolean bl) {
# this.stroke = bl;
# public void setW(long l) {
# protected Boolean flipV;
# public Vector analysis = new Vector();
# double analysisSleep = 0.0D;
# public Vector bluetoothInputs = new Vector();
# public Vector bluetoothOutputs = new Vector();
# long crc32 = 0L; } }
# ============================================================
#
# [False Negative #5] - Originally from 'LVDAndro_84304_file'
# Model Confidence it was SAFE: 99.98%
# ----------------------------------------
# public class DummyClass { public void dummyMethod() { sSounds.add(sound);
# protected static void downloadData(Context context, Runnable runnable) {
# context.setProgressStyle(1);
# context.setCanceledOnTouchOutside(false);
# runnable = new -$$Lambda$Sounds$iJSOl-pseCunlcJXFFxU9chQx24(runnable, (ProgressDialog)context);
# LoadBuilder<Builders$Any$B> loadBuilder = Ion.with((Context)App.get());
# ArrayList<Sound> arrayList = new ArrayList<Sound>();
# for (Sound sound : sSounds) {
# if (!(sound instanceof BundledSound) && !(sound instanceof UserSound)) continue;
# arrayList.add(sound);
# public static Sound getSound(int n) { } }
# ============================================================
#
# [False Negative #6] - Originally from 'LVDAndro_190913_file'
# Model Confidence it was SAFE: 99.97%
# ----------------------------------------
# public class DummyClass { public void dummyMethod() { this.socket = call;
# return call != null;
# private void tryReAddingEventToFrontOfQueue(final E e) {
# if (!this.deque.offer(e, this.eventDelayLimit.getMilliseconds(), TimeUnit.MILLISECONDS)) {
# sb.append(this.eventDelayLimit);
# sb.append(this.name);
# this.addError(sb.toString());
# this.deque = (BlockingDeque<E>)this.queueFactory.newLinkedBlockingDeque(this.queueSize);
# sb3.append(this.remoteHost);
# sb3.append(this.port);
# this.peerId = sb3.toString(); } }
# ============================================================
#
# [False Negative #7] - Originally from 'LVDAndro_164636_file'
# Model Confidence it was SAFE: 99.97%
# ----------------------------------------
# public class DummyClass { public void dummyMethod() { public static synchronized void popGenerator() {
# if (generators.size() == 1) {
# Game.reportException(new RuntimeException("tried to pop the last random number generator!"));
# generators.pop();
# public static synchronized void pushGenerator() {
# generators.push(new java.util.Random());
# public static synchronized void resetGenerators() {
# ArrayDeque<java.util.Random> arrayDeque = new ArrayDeque<>();
# generators = arrayDeque;
# arrayDeque.push(new java.util.Random());
# public static synchronized <T> void shuffle(List<? extends T> list) { } }
# ============================================================
#
# [False Negative #8] - Originally from 'LVDAndro_102817_file'
# Model Confidence it was SAFE: 99.97%
# ----------------------------------------
# public class DummyClass { Headers.Companion companion = Headers.Companion;
# Intrinsics.checkExpressionValueIsNotNull(headerFields, "connection.headerFields");
# Headers from = companion.from(headerFields);
# Iterator<T> it = from.get((Object) Headers.TRANSFER_ENCODING).iterator();
# CollectionsKt.addAll(arrayList, StringsKt.split$default((CharSequence) it.next(), new char[]{','}, false, 0, 6, (Object) null));
# arrayList3.add(StringsKt.trim((CharSequence) str).toString());
# String str2 = (String) CollectionsKt.lastOrNull(from.get((Object) Headers.CONTENT_ENCODING));
# String str3 = (String) CollectionsKt.lastOrNull(from.get((Object) Headers.CONTENT_LENGTH));
# objectRef.element = str3 != null ? (T) Long.valueOf(Long.parseLong(str3)) : null;
# Boolean decodeContent2 = request.getExecutionOptions().getDecodeContent();
# boolean z3 = (decodeContent2 != null ? decodeContent2.booleanValue() : this.decodeContent) && str2 != null && (Intrinsics.areEqual(str2, "identity") ^ true); }
# ============================================================
#
# [False Negative #9] - Originally from 'LVDAndro_373963_file'
# Model Confidence it was SAFE: 99.97%
# ----------------------------------------
# public class DummyClass { public void dummyMethod() { object.H0(object.L0("market://details"));
# if (object.equals(this.e.p0.getResources().getString(2131755047))) {
# if (intent.resolveActivity(object.p0.getPackageManager()) == null) return;
# object.H0(intent);
# if (!object.equals(this.e.p0.getResources().getString(2131755049))) return;
# Object object2 = object.i().getPackageManager().queryIntentActivities(intent, 0);
# hashSet.add(((ResolveInfo)object3.next()).activityInfo.name);
# if (!object2.hasNext()) return;
# } while (hashSet.contains(object3.activityInfo.name));
# intent.setPackage(object3.activityInfo.packageName);
# object.p0.startActivity(intent); } }
# ============================================================
#
# [False Negative #10] - Originally from 'LVDAndro_310332_file'
# Model Confidence it was SAFE: 99.95%
# ----------------------------------------
# public class DummyClass { package com.igormaznitsa.piratedice;
# this.getWindow().setFlags(1024, 2098304);
# Model.dispose();
# Model.getInstance().startTurn();
# Model.getInstance().nextType();
# case 2131099653: {
# Model.getInstance().setType(Type.PROFESSIONAL);
# Model.getInstance().setType(Type.REDESIGNED);
# Model.getInstance().setType(Type.STANDARD);
# Model.getInstance().setPaused(true);
# switch (.$SwitchMap$com$igormaznitsa$piratedice$model$Type[type.ordinal()]) { }
# ============================================================
#
# [False Negative #11] - Originally from 'LVDAndro_120515_file'
# Model Confidence it was SAFE: 99.95%
# ----------------------------------------
# public class DummyClass { public void dummyMethod() { MediaParsingService$updateStorages$2(MediaParsingService mediaParsingService, Continuation continuation) {
# this.this$0 = mediaParsingService;
# return new MediaParsingService$updateStorages$2(this.this$0, continuation);
# public final Object invoke(CoroutineScope coroutineScope, Continuation<? super Pair<? extends List<? extends String>, ? extends String[]>> continuation) {
# return ((MediaParsingService$updateStorages$2) create(coroutineScope, continuation)).invokeSuspend(Unit.INSTANCE);
# return new Pair(AndroidDevices.INSTANCE.getExternalStorageDirectories(), MediaParsingService.access$getMedialibrary$p(this.this$0).getDevices()); } }
# ============================================================
#
# [False Negative #12] - Originally from 'LVDAndro_180694_file'
# Model Confidence it was SAFE: 99.95%
# ----------------------------------------
# public class DummyClass { public void dummyMethod() { float timeStamp = keyFrame2.getTimeStamp() - keyFrame3.getTimeStamp();
# transforms.put(str2, JointTransform.ofInterpolation(jointTransform2, keyFrame4.getTransforms().get(str2), keyFrame4 != keyFrame3 ? timeStamp / (keyFrame4.getTimeStamp() - keyFrame3.getTimeStamp()) : 0.0f, jointTransform2, keyFrame5.getTransforms().get(str2), keyFrame5 != keyFrame3 ? timeStamp / (keyFrame5.getTimeStamp() - keyFrame3.getTimeStamp()) : 0.0f, jointTransform2, keyFrame6.getTransforms().get(str2), keyFrame6 != keyFrame3 ? timeStamp / (keyFrame6.getTimeStamp() - keyFrame3.getTimeStamp()) : 0.0f, jointTransform2, keyFrame7.getTransforms().get(str2), keyFrame7 != keyFrame3 ? timeStamp / (keyFrame7.getTimeStamp() - keyFrame3.getTimeStamp()) : 0.0f, jointTransform2, keyFrame8.getTransforms().get(str2), keyFrame8 != keyFrame3 ? timeStamp / (keyFrame8.getTimeStamp() - keyFrame3.getTimeStamp()) : 0.0f, jointTransform2, keyFrame9.getTransforms().get(str2), keyFrame9 != keyFrame3 ? timeStamp / (keyFrame9.getTimeStamp() - keyFrame3.getTimeStamp()) : 0.0f, jointTransform2, keyFrame10.getTransforms().get(str2), keyFrame10 != keyFrame3 ? timeStamp / (keyFrame10.getTimeStamp() - keyFrame3.getTimeStamp()) : 0.0f, jointTransform2, keyFrame11.getTransforms().get(str2), keyFrame11 != keyFrame3 ? timeStamp / (keyFrame11.getTimeStamp() - keyFrame3.getTimeStamp()) : 0.0f, jointTransform2, keyFrame12.getTransforms().get(str2), keyFrame12 != keyFrame3 ? timeStamp / (keyFrame12.getTimeStamp() - keyFrame3.getTimeStamp()) : 0.0f));
# hashSet = hashSet;
# rootJoint = rootJoint;
# keyFrames = keyFrames;
# Log.d("Animator", "Completed Keyframe: " + keyFrame2);
# animatedModel.getAnimation().setInitialized(true);
# Log.i("Animator", "Initialized " + animatedModel.getId() + str + keyFrames.length + " key frames");
# private void increaseAnimationTime(AnimatedModel animatedModel) {
# float uptimeMillis = (((float) SystemClock.uptimeMillis()) / 1000.0f) * this.speed;
# this.animationTime = uptimeMillis; } }
# ============================================================
#
# [False Negative #13] - Originally from 'LVDAndro_3920_file'
# Model Confidence it was SAFE: 99.95%
# ----------------------------------------
# public class DummyClass { List<String> list = object;
# list = new ArrayList<String>();
# object = f2.b();
# this.a(list, f2.a(), (String)object, f2.c(), bl, this.e.d(), this.e.e());
# private void a(List<String> list, String string2) {
# list = new ArrayList<String>();
# this.a(list, null, null, string2, null, this.e.d(), this.e.e());
# private void a(List<String> object, String string2, String string3, String string4, Boolean bl, String string5, String string6) {
# String string7 = AdUtil.a(this.b.f.a());
# Object object2 = b.a();
# String string8 = object2.b().toString(); }
# ============================================================
#
# [False Negative #14] - Originally from 'LVDAndro_261191_file'
# Model Confidence it was SAFE: 99.94%
# ----------------------------------------
# public class DummyClass { public void dummyMethod() { this.setDirectionArrow(((BitmapDrawable)mapView.getContext().getResources().getDrawable(R.drawable.person)).getBitmap(), ((BitmapDrawable)mapView.getContext().getResources().getDrawable(R.drawable.round_navigation_white_48)).getBitmap());
# new Thread((Runnable)iterator.next()).start();
# } else if (motionEvent.getAction() == 2 && this.isFollowLocationEnabled()) {
# this.mDirectionArrowCenterX = (float)this.mDirectionArrowBitmap.getWidth() / 2.0f - 0.5f;
# protected void setLocation(Location location) {
# public class MapQuestRoadManager extends RoadManager {
# final File osmdroidBasePath = this.getOsmdroidBasePath();
# File osmdroidTileCache = this.getOsmdroidTileCache();
# this.setOsmdroidBasePath(new File(sharedPreferences.getString("osmdroid.basePath", this.getOsmdroidBasePath().getAbsolutePath())));
# this.setOsmdroidTileCache(new File(sharedPreferences.getString("osmdroid.cachePath", this.getOsmdroidTileCache().getAbsolutePath())));
# this.expirationOverride = sharedPreferences.getLong("osmdroid.ExpirationOverride", -1L); } }
# ============================================================
#
# [False Negative #15] - Originally from 'LVDAndro_197646_file'
# Model Confidence it was SAFE: 99.94%
# ----------------------------------------
# public class DummyClass { public void dummyMethod() { public searchmauze() {
# searchmauze.array_sort.getFilter().filter(charSequence);
# static /* synthetic */ void access$1(final searchmauze searchmauze, final ProgressDialog progress) {
# searchmauze.progress = progress;
# public void addmauze_fromws() {
# searchmauze.uid = this.getIntent().getStringExtra("userid");
# searchmauze.array_sort = (ArrayAdapter<String>)new ArrayAdapter((Context)this, 17367043, (Object[])array);
# this.lv.setAdapter((ListAdapter)searchmauze.array_sort);
# searchmauze.selectedmauze = string.toString();
# searchmauze.access$1(searchmauze.this, new ProgressDialog((Context)searchmauze.this));
# searchmauze.this.progress.getProgress(); } }
# ============================================================
#
# [False Negative #16] - Originally from 'Draper_363906_file'
# Model Confidence it was SAFE: 99.94%
# ----------------------------------------
# void dummy_function() { notify_file_flags_changed(const DjVuFile *file,
#                                            long mask, long)
# {
#   if (mask & (DjVuFile::ALL_DATA_PRESENT | DjVuFile::DATA_PRESENT |
#               DjVuFile::DECODE_FAILED | DjVuFile::DECODE_STOPPED |
#               DjVuFile::STOPPED | DjVuFile::DECODE_STOPPED ))
#     {
#       GMonitorLock lock(&monitor);
#       monitor.signal();
#     }
# } }
# ============================================================
#
# [False Negative #17] - Originally from 'LVDAndro_199128_file'
# Model Confidence it was SAFE: 99.93%
# ----------------------------------------
# public class DummyClass { public void dummyMethod() { ((MainActivity)VehicleSelectionActivity.this.getActivity()).currentVehicle = var3x;
# String var4 = ((MainActivity)this.getActivity()).userId;
# var6.setTag("VEHICLES");
# this.queue.add(var6);
# String var5 = ((MainActivity)VehicleSelectionActivity.this.getActivity()).userId;
# String var6 = ((MainActivity)VehicleSelectionActivity.this.getActivity()).token;
# VehicleSelectionActivity.this.queue.cancelAll((Object)"VEHICLES");
# VehicleSelectionActivity.this.queue.add(var8);
# View var4 = var1.inflate(2130903057, (ViewGroup)null);
# this.currentSelection = ((MainActivity)VehicleSelectionActivity.this.getActivity()).currentVehicle;
# var9 = VehicleSelectionActivity.this.getLayoutInflater((Bundle)null).inflate(2130903058, (ViewGroup)null); } }
# ============================================================
#
# [False Negative #18] - Originally from 'LVDAndro_299675_file'
# Model Confidence it was SAFE: 99.92%
# ----------------------------------------
# public class DummyClass { this.db = new GalleryTrashDb(context2, 1);
# this.db = new AlbumFilesDb(context2);
# int screenWidthByColumns = Helpers.getScreenWidthByColumns(context2);
# this.thumbSize = screenWidthByColumns;
# this.lm = autoFitGridLayoutManager;
# this.picasso = new Picasso.Builder(context2).addRequestHandler(new StinglePicassoLoader(context2, this.db, screenWidthByColumns, str)).build();
# getAvailableDates();
# this.filePropsCache.evictAll();
# this.picasso.evictAll();
# public class GalleryVH extends RecyclerView.ViewHolder implements View.OnClickListener, View.OnLongClickListener {
# public ImageView noCloudIcon; }
# ============================================================
#
# [False Negative #19] - Originally from 'LVDAndro_278020_file'
# Model Confidence it was SAFE: 99.92%
# ----------------------------------------
# public class DummyClass { public void dummyMethod() { Runnable c;
# Runnable d;
# public SearchDemo() {
# this.a = this.getIntent();
# (this.r = (TextView)this.findViewById(2131492981)).setMovementMethod((MovementMethod)new ScrollingMovementMethod());
# this.r.append((CharSequence)"Search Topic 1\n");
# this.b.postDelayed(this.c, 2000L);
# this.b.postDelayed(this.d, 3000L);
# this.getMenuInflater().inflate(2131558408, menu);
# return menuItem.getItemId() == 2131492993 || super.onOptionsItemSelected(menuItem);
# import android.support.a.f.class_204; } }
# ============================================================
#
# [False Negative #20] - Originally from 'LVDAndro_271604_file'
# Model Confidence it was SAFE: 99.92%
# ----------------------------------------
# public class DummyClass { public void dummyMethod() { singleImplementationSanityCheck();
# ArrayList<URL> list;
# final Enumeration<URL> resources = LoggerFactory.class.getClassLoader().getResources(LoggerFactory.STATIC_LOGGER_BINDER_PATH);
# list = new ArrayList<URL>();
# list.add(resources.nextElement());
# if (n >= list.size()) {
# Util.reportFailure("Error getting resources from path", ex);
# Util.reportFailure("Found binding in [" + list.get(n) + "]");
# for (int i = 0; i < LoggerFactory.API_COMPATIBILITY_LIST.length; ++i) {
# if (LoggerFactory.API_COMPATIBILITY_LIST[i].equals(requested_API_VERSION)) {
# Util.reportFailure("Unexpected problem occured during version sanity check", t); } }
# ============================================================
